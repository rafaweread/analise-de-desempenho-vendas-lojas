# %% [markdown]
# ### Análise exploratória dos dados e indicadores das lojas

# %%
import pandas as pd
import sqlalchemy
import seaborn as sns

# %%
loja05 = pd.read_excel(f"Base\Estudo de caso.xlsx", sheet_name="LOJA 05 SHOP S")
df01 = pd.DataFrame(loja05)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16892\2860484408.py:1: SyntaxWarning: invalid escape sequence '\E'
#   loja05 = pd.read_excel(f"Base\Estudo de caso.xlsx", sheet_name="LOJA 05 SHOP S")

# %%
df01.head(5)
# Out:
#                          Unnamed: 0 01/12/2024 a 02/12/2028 Unnamed: 2  \
# 0                           LOJA 05              1° SEMANA   1° SEMANA
# 1                               NaN                  ORÇADO  REALIZADO
# 2  Alcance de Meta Receita PEF Loja            18200.437687    9618.45
# 3                       Venda Média              165.317194   160.3075
# 4                 Itens por Boleto                     3.01   2.833333
#
#    Unnamed: 3 03/12/2024 a 09/12/2028 Unnamed: 5  Unnamed: 6  \
# 0  1° SEMANA2              2° SEMANA   2° SEMANA  2° SEMANA2
# 1           %                  ORÇADO  REALIZADO           %
# 2    0.528474            45609.962396    55369.5    1.213978
# 3    0.969696               108.85467  165.28209    1.518374
# 4    0.941307                    3.01   3.143284     1.04428
#
#   10/12/2024 a 16/12/2028  Unnamed: 8  Unnamed: 9  ... Unnamed: 18  \
# 0              3° SEMANA    3° SEMANA  3° SEMANA2  ...  ACUMULADO3
# ...

# %%
df_transportado = df01.transpose()
print(df_transportado)
# Out:
#                                                                      0   \
# Unnamed: 0                                                      LOJA 05
# 01/12/2024 a 02/12/2028                                      1° SEMANA
# Unnamed: 2                                                    1° SEMANA
# Unnamed: 3                                                   1° SEMANA2
# 03/12/2024 a 09/12/2028                                      2° SEMANA
# Unnamed: 5                                                    2° SEMANA
# Unnamed: 6                                                   2° SEMANA2
# 10/12/2024 a 16/12/2028                                      3° SEMANA
# Unnamed: 8                                                    3° SEMANA
# Unnamed: 9                                                   3° SEMANA2
# 17/12/2024 a 23/12/2028                                      4° SEMANA
# Unnamed: 11                                                   4° SEMANA
# ...
